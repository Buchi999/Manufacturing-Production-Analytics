# %%
import pandas as pd

# %%
df=pd.read_csv("manufacturing_production_data.csv")

# %% [markdown]
# # TASK 1: DATA EXPLORATION

# %% [markdown]
# ## STRUCTURE OVERVIEW

# %% [markdown]
# ### TO SHOW TOTAL ROWS AND COLUMNS

# %%
df.shape
# Out:
# (1000, 20)

# %%
df.head(5)
# Out:
#   Production ID Production Date    Factory Production Line      Shift  \
# 0        P00001      2025-05-21  Factory A          Line B    Morning
# 1        P00002      2025-04-23  Factory B          Line C    Morning
# 2        P00003      2025-10-02  Factory A          Line D    Morning
# 3        P00004      2025-05-23  Factory B          Line C    Morning
# 4        P00005      2025-01-29  Factory A          Line A  Afternoon
#
#   Machine ID    Machine Type Operator ID Product Category  Planned Production  \
# 0       M107          Manual      OP1095  Air Conditioner                 237
# 1       M111          Manual      OP1055  Washing Machine                 459
# 2       M136  Semi-Automatic      OP1081  Air Conditioner                 202
# 3       M124  Semi-Automatic      OP1027  Washing Machine                 231
# 4       M126  Semi-Automatic      OP1009       Television                 292
#
#    Actual Production  Defective Units  Downtime (Minutes)  Production Hours  \
# 0                249                2                75.0                12
# 1                421               17                19.0                 9
# 2                159                5                73.0                 9
# 3                198                2                77.0                 9
# 4                266               18               112.0                10
#
#    Energy Consumption (kWh)  Maintenance Cost ($)  Unit Production Cost ($)  \
# 0                       332                171.51                    117.92
# 1                      1081                907.83                     64.42
# 2                      1021                266.93                    306.04
# 3                       846               1849.90                     94.45
# 4                       517               1673.05                    193.14
#
#    Temperature (°C)  Humidity (%)  Quality Inspection Score
# 0              28.1            36                      82.4
# 1              19.9            57                      84.1
# 2              33.5            40                      94.2
# 3              25.6            75                      87.5
# 4              36.3            64                      65.7

# %% [markdown]
# ### SHOWS DTYPES AND NON NULL COUNT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Production ID             1000 non-null   object
#  1   Production Date           1000 non-null   object
#  2   Factory                   1000 non-null   object
#  3   Production Line           1000 non-null   object
#  4   Shift                     1000 non-null   object
#  5   Machine ID                1000 non-null   object
#  6   Machine Type              1000 non-null   object
#  7   Operator ID               1000 non-null   object
#  8   Product Category          1000 non-null   object
#  9   Planned Production        1000 non-null   int64
#  10  Actual Production         1000 non-null   int64
#  11  Defective Units           1000 non-null   int64
#  12  Downtime (Minutes)        985 non-null    float64
#  13  Production Hours          1000 non-null   int64
#  14  Energy Consumption (kWh)  1000 non-null   int64
#  15  Maintenance Cost ($)      1000 non-null   float64
#  16  Unit Production Cost ($)  1000 non-null   float64
#  17  Temperature (°C)          1000 non-null   float64
#  18  Humidity (%)              1000 non-null   int64
#  19  Quality Inspection Score  985 non-null    float64
# dtypes: float64(5), int64(6), object(9)
# memory usage: 156.4+ KB

# %%
df.dtypes
# Out:
# Production ID                object
# Production Date              object
# Factory                      object
# Production Line              object
# Shift                        object
# Machine ID                   object
# Machine Type                 object
# Operator ID                  object
# Product Category             object
# Planned Production            int64
# Actual Production             int64
# Defective Units               int64
# Downtime (Minutes)          float64
# Production Hours              int64
# Energy Consumption (kWh)      int64
# Maintenance Cost ($)        float64
# Unit Production Cost ($)    float64
# Temperature (°C)            float64
# Humidity (%)                  int64
# Quality Inspection Score    float64
# dtype: object

# %% [markdown]
# ## DATA QUALITY CHECKS

# %% [markdown]
# ### TO SHOW MISSING VALUES PER COLUMN

# %%
df.isnull().sum()
# Out:
# Production ID                0
# Production Date              0
# Factory                      0
# Production Line              0
# Shift                        0
# Machine ID                   0
# Machine Type                 0
# Operator ID                  0
# Product Category             0
# Planned Production           0
# Actual Production            0
# Defective Units              0
# Downtime (Minutes)          15
# Production Hours             0
# Energy Consumption (kWh)     0
# Maintenance Cost ($)         0
# Unit Production Cost ($)     0
# Temperature (°C)             0
# Humidity (%)                 0
# Quality Inspection Score    15
# dtype: int64

# %% [markdown]
# ### TO SHOW THE SUM OF DUPLICATE ROWS

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### TO SHOW CARDINALITY PER COLUMN

# %%
df.nunique()
# Out:
# Production ID               1000
# Production Date              342
# Factory                        3
# Production Line                4
# Shift                          3
# Machine ID                    40
# Machine Type                   3
# Operator ID                  100
# Product Category               5
# Planned Production           309
# Actual Production            339
# Defective Units               39
# Downtime (Minutes)           121
# Production Hours               4
# Energy Consumption (kWh)     577
# Maintenance Cost ($)         999
# Unit Production Cost ($)     990
# Temperature (°C)             200
# Humidity (%)                  51
# Quality Inspection Score     372
# dtype: int64

# %% [markdown]
# ### TO SHOW NUMERIC SUMMARY STATS

# %%
df.describe()
# Out:
#        Planned Production  Actual Production  Defective Units  \
# count         1000.000000        1000.000000      1000.000000
# mean           341.586000         319.201000        12.561000
# std             93.816428          96.878946         8.670955
# min            180.000000         123.000000         0.000000
# 25%            257.000000         236.000000         6.000000
# 50%            341.500000         318.000000        11.000000
# 75%            425.000000         402.000000        18.000000
# max            500.000000         513.000000        41.000000
#
#        Downtime (Minutes)  Production Hours  Energy Consumption (kWh)  \
# count          985.000000        1000.00000               1000.000000
# mean            60.021320           9.80000                736.268000
# std             34.246188           1.46429                256.814555
# min              0.000000           8.00000                301.000000
# 25%             30.000000           9.00000                511.750000
# 50%             60.000000          10.00000                729.000000
# 75%             89.000000          12.00000                959.250000
# max            120.000000          12.00000               1199.000000
#
#        Maintenance Cost ($)  Unit Production Cost ($)  Temperature (°C)  \
# count            1000.00000               1000.000000       1000.000000
# mean             1317.89713                241.725410         27.977000
# std               701.21222                119.106266          5.720311
# min               100.22000                 26.140000         18.000000
# 25%               692.83000                143.912500         23.200000
# 50%              1326.17000                243.530000         28.000000
# 75%              1911.50250                346.287500         32.900000
# max              2494.92000                449.020000         38.000000
#
#        Humidity (%)  Quality Inspection Score
# count   1000.000000                985.000000
# mean      60.055000                 79.978782
# std       14.662775                 11.614751
# min       35.000000                 60.100000
# 25%       47.000000                 70.100000
# 50%       60.000000                 79.800000
# 75%       73.000000                 90.200000
# max       85.000000                100.000000

# %%
df["Production Date"].min(), df["Production Date"].max()
# Out:
# ('2025-01-01', '2025-12-31')

# %% [markdown]
# # TASK 2: DATA CLEANING

# %% [markdown]
# ## REMOVE DUPLICATES

# %%
df=df.drop_duplicates()

# %% [markdown]
# ## FIXING DATA TYPES

# %%
df["Production Date"] = pd.to_datetime(df["Production Date"], errors="coerce")

# %% [markdown]
# ## HANDLING MISSING VALUES

# %% [markdown]
# ### NUMERIC COLUMNS

# %%
numeric_cols = ["Planned Production","Actual Production","Defective Units","Downtime (Minutes)","Production Hours","Energy Consumption (kWh)","Maintenance Cost ($)","Unit Production Cost ($)","Temperature (°C)","Humidity (%)","Quality Inspection Score"]
for col in numeric_cols:
 df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ### CATEGORICAL COLUMNS - FILL WITH MODE OR A PLACE HOLDER

# %%
categorical_cols = ["Factory","Production Line","Shift","Machine Type","Product Category"]
for col in categorical_cols:
 df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# ### DROP ROWS THAT ARE MISSING CRITICAL IDS

# %%
df = df.dropna(subset=["Production ID","Machine ID","Operator ID"])

# %% [markdown]
# ## STANDARDIZE TEXTS

# %%
for col in categorical_cols + ["Machine ID","Operator ID","Production ID"]:
 df[col] = df[col].astype(str).str.strip().str.title()

# %% [markdown]
# ### CHECK FOR INCONSISTENT VARIANTS AFTER STANDARDIZING

# %%
df["Factory"].unique()
# Out:
# array(['Factory A', 'Factory B', 'Factory C'], dtype=object)

# %% [markdown]
# ## HANDLING INVALID VALUES

# %% [markdown]
# ### NO NEGATIVE VALUES ALLOWED IN THESE

# %%
non_negative_cols = ["Planned Production","Actual Production","Defective Units","Downtime (Minutes)","Production Hours","Energy Consumption (kWh)","Maintenance Cost ($)","Unit Production Cost ($)"]
for col in non_negative_cols:
 df = df[df[col] >= 0]

# %% [markdown]
# ### DEFECTIVE UNITS CAN'T EXCEED ACTUAL PRODUCTION

# %%
df = df[df["Defective Units"] <= df["Actual Production"]]

# %% [markdown]
# ## VALIDATE LOGICAL RANGES

# %% [markdown]
# ### HUMIDITY SHOULD BE 0-100%

# %%
df = df[(df["Humidity (%)"] >= 0) & (df["Humidity (%)"] <= 100)]

# %% [markdown]
# ### QUALITY INSPECTION SCORE - CHECK THE EXPECTED SCALE IN YOUR DATASET

# %%
df = df[(df["Quality Inspection Score"] >= 0) & (df["Quality Inspection Score"] <= 100)]

# %% [markdown]
# ### TEMPERATURE - FLAG UNLIKELY EXTREMES FOR A FACTORY FLOOR (ADJUST BOUNDS TO YOUR CONTEXT)

# %%
df = df[(df["Temperature (°C)"] >= 0) & (df["Temperature (°C)"] <= 60)]

# %% [markdown]
# ## HANDLE OUTLIERS IN CONTINUOUS VARIABLES

# %%
def remove_outliers_iqr(data, col):
 Q1 = data[col].quantile(0.25)
 Q3 = data[col].quantile(0.75)
 IQR = Q3 - Q1
 lower = Q1 - 1.5 * IQR
 upper = Q3 + 1.5 * IQR
 return data[(data[col] >= lower) & (data[col] <= upper)]
for col in ["Energy Consumption (kWh)","Maintenance Cost ($)","Unit Production Cost ($)"]:
 df = remove_outliers_iqr(df, col)

# %% [markdown]
# ## RESET INDEX AND EXPORT CLEANED DATA

# %%
df = df.reset_index(drop=True)
df.to_csv("manufacturing_production_data_cleaned.csv", index=False)

# %% [markdown]
# # TASK 3: Exploratory Data Analysis

# %% [markdown]
# ## PRODUCTION PERFORMANCE OVERVIEW

# %%
df["Production Efficiency (%)"] = (df["Actual Production"] / df["Planned Production"]) * 100

# %%
df["Defect Rate (%)"] = (df["Defective Units"] / df["Actual Production"]) * 100

# %%
df[["Planned Production","Actual Production","Production Efficiency (%)","Defect Rate (%)"]].describe()
# Out:
#        Planned Production  Actual Production  Production Efficiency (%)  \
# count         1000.000000        1000.000000                1000.000000
# mean           341.586000         319.201000                  92.849842
# std             93.816428          96.878946                   7.620315
# min            180.000000         123.000000                  67.213115
# 25%            257.000000         236.000000                  87.959335
# 50%            341.500000         318.000000                  93.178055
# 75%            425.000000         402.000000                  99.147558
# max            500.000000         513.000000                 107.978723
#
#        Defect Rate (%)
# count      1000.000000
# mean          3.934893
# std           2.326746
# min           0.000000
# 25%           1.992055
# 50%           3.975734
# 75%           6.008033
# max           7.992203

# %% [markdown]
# ## FACTORY PERFORMANCE COMPARISON

# %%
factory_perf = df.groupby("Factory").agg(
 total_planned=("Planned Production","sum"),
 total_actual=("Actual Production","sum"),
 avg_efficiency=("Production Efficiency (%)","mean"),
 avg_defect_rate=("Defect Rate (%)","mean"),
 avg_downtime=("Downtime (Minutes)","mean")
).sort_values("avg_efficiency", ascending=False)
factory_perf
# Out:
#            total_planned  total_actual  avg_efficiency  avg_defect_rate  \
# Factory
# Factory B         121539        113887       93.175696         3.954772
# Factory C         109341        102202       92.961246         3.855589
# Factory A         110706        103112       92.391683         3.992254
#
#            avg_downtime
# Factory
# Factory B     60.214900
# Factory C     57.280864
# Factory A     62.529052

# %% [markdown]
# ## PRODUCTION LINE PERFORMANCE

# %%
line_perf = df.groupby(["Factory","Production Line"]).agg(
 avg_efficiency=("Production Efficiency (%)","mean"),
 avg_defect_rate=("Defect Rate (%)","mean"),
 total_downtime=("Downtime (Minutes)","sum")
).sort_values("avg_efficiency", ascending=False)
line_perf
# Out:
#                            avg_efficiency  avg_defect_rate  total_downtime
# Factory   Production Line
# Factory C Line D                94.190903         3.777727          5650.0
#           Line A                93.646311         3.970981          4170.0
# Factory B Line C                93.616045         3.587027          5173.0
#           Line A                93.549419         4.021147          5302.0
# Factory A Line A                92.827203         3.894962          6032.0
# Factory B Line B                92.792035         4.373636          5201.0
#           Line D                92.728489         3.854557          5339.0
# Factory A Line D                92.673032         3.937529          4451.0
#           Line B                92.345653         3.938178          5309.0
# Factory C Line C                92.294050         3.783711          4606.0
# Factory A Line C                91.551766         4.247559          4655.0
# Factory C Line B                91.297406         3.907939          4133.0

# %% [markdown]
# ## MACHINE PERFORMANCE

# %%
machine_perf = df.groupby(["Machine ID","Machine Type"]).agg(
 avg_efficiency=("Production Efficiency (%)","mean"),
 avg_defect_rate=("Defect Rate (%)","mean"),
 avg_downtime=("Downtime (Minutes)","mean"),
 avg_maintenance_cost=("Maintenance Cost ($)","mean")
).sort_values("avg_downtime", ascending=False)
machine_perf.head(10)
# Out:
#                            avg_efficiency  avg_defect_rate  avg_downtime  \
# Machine ID Machine Type
# M104       Automatic            92.386813         3.309410     87.111111
# M119       Automatic            90.126172         5.274432     85.857143
# M114       Manual               90.460527         5.017235     85.000000
# M113       Automatic            91.383016         5.340916     82.000000
# M137       Semi-Automatic       89.416193         5.500555     79.571429
# M123       Automatic            93.070441         4.867155     78.375000
# M116       Automatic            95.319416         2.844688     77.833333
# M129       Manual               89.812334         3.628679     76.222222
# M104       Semi-Automatic       90.587333         2.159586     76.166667
# M106       Manual               95.341302         3.334269     75.833333
#
#                            avg_maintenance_cost
# Machine ID Machine Type
# M104       Automatic                1212.322222
# M119       Automatic                1596.205714
# M114       Manual                   1324.955714
# M113       Automatic                1258.353333
# M137       Semi-Automatic           1542.892857
# M123       Automatic                1232.800000
# M116       Automatic                1167.381667
# M129       Manual                   1253.786667
# M104       Semi-Automatic           1789.931667
# M106       Manual                   1293.378333

# %% [markdown]
# ## PRODUCT QUALITY ANALYSIS

# %%
quality_by_product = df.groupby("Product Category").agg(
 avg_quality_score=("Quality Inspection Score","mean"),
 avg_defect_rate=("Defect Rate (%)","mean")
).sort_values("avg_quality_score")
quality_by_product
# Out:
#                   avg_quality_score  avg_defect_rate
# Product Category
# Microwave                 78.909406         3.887179
# Washing Machine           79.472906         4.312970
# Refrigerator              79.728358         3.798187
# Television                80.323834         3.939827
# Air Conditioner           81.470149         3.732974

# %% [markdown]
# ## OPERATIONAL EFFICIENCY

# %%
df["Cost per Unit ($)"] = df["Unit Production Cost ($)"]
efficiency_summary = df.groupby("Factory").agg(
 avg_cost_per_unit=("Cost per Unit ($)","mean"),
 avg_production_hours=("Production Hours","mean"),
 avg_efficiency=("Production Efficiency (%)","mean")
)
efficiency_summary
# Out:
#            avg_cost_per_unit  avg_production_hours  avg_efficiency
# Factory
# Factory A         239.412936              9.755352       92.391683
# Factory B         237.894556              9.710602       93.175696
# Factory C         248.185741              9.941358       92.961246

# %% [markdown]
# ## DOWNTIME ANALYSIS

# %%
downtime_by_shift = df.groupby("Shift")["Downtime (Minutes)"].mean()
downtime_by_shift
# Out:
# Shift
# Afternoon    57.254601
# Morning      61.249258
# Night        61.468843
# Name: Downtime (Minutes), dtype: float64

# %%
downtime_by_machine_type = df.groupby("Machine Type")["Downtime (Minutes)"].mean()
downtime_by_machine_type
# Out:
# Machine Type
# Automatic         58.824615
# Manual            60.583832
# Semi-Automatic    60.609971
# Name: Downtime (Minutes), dtype: float64

# %% [markdown]
# ## ENERGY CONSUMPTION ANALYSIS

# %%
energy_by_factory = df.groupby("Factory")["Energy Consumption (kWh)"].agg(["mean","sum"])
energy_by_factory
# Out:
#                  mean     sum
# Factory
# Factory A  740.782875  242236
# Factory B  720.263610  251372
# Factory C  748.950617  242660

# %%
energy_vs_production = df[["Energy Consumption (kWh)","Actual Production"]].corr()
energy_vs_production
# Out:
#                           Energy Consumption (kWh)  Actual Production
# Energy Consumption (kWh)                  1.000000          -0.022467
# Actual Production                        -0.022467           1.000000

# %% [markdown]
# ## MAINTENANCE ANALYSIS

# %%
maintenance_by_machine_type = df.groupby("Machine Type")["Maintenance Cost ($)"].agg(["mean","sum"])
maintenance_by_machine_type
# Out:
#                        mean        sum
# Machine Type
# Automatic       1305.507815  424290.04
# Manual          1279.638892  427399.39
# Semi-Automatic  1367.178006  466207.70

# %%
maintenance_vs_downtime = df[["Maintenance Cost ($)","Downtime (Minutes)"]].corr()
maintenance_vs_downtime
# Out:
#                       Maintenance Cost ($)  Downtime (Minutes)
# Maintenance Cost ($)              1.000000            0.063544
# Downtime (Minutes)                0.063544            1.000000

# %% [markdown]
# ## WORKFORCE (OPERATOR) PERFORMANCE

# %%
operator_perf = df.groupby("Operator ID").agg(
 avg_efficiency=("Production Efficiency (%)","mean"),
 avg_defect_rate=("Defect Rate (%)","mean"),
 total_units=("Actual Production","sum")
).sort_values("avg_efficiency", ascending=False)

# %%
operator_perf.head(10)
# Out:
#              avg_efficiency  avg_defect_rate  total_units
# Operator ID
# Op1080            97.702879         1.815301         1704
# Op1057            97.452005         3.595794         3100
# Op1085            97.364854         4.755754         3142
# Op1083            97.257240         4.662301         2501
# Op1076            96.943748         3.176861         2288
# Op1071            96.669185         3.499554         3914
# Op1001            96.545833         4.333693         3194
# Op1100            96.170398         4.633289         1710
# Op1054            96.055424         4.116938         3989
# Op1073            95.806138         3.312376         3591

# %%
operator_perf.tail(10)
# Out:
#              avg_efficiency  avg_defect_rate  total_units
# Operator ID
# Op1038            89.888107         4.860529         2545
# Op1050            89.796488         4.047216         2662
# Op1068            89.786378         3.375607         2683
# Op1028            89.759256         4.759463         1979
# Op1024            89.483379         2.433750         1170
# Op1003            89.363926         4.726283         3391
# Op1065            89.325143         3.940775         3242
# Op1059            87.490796         3.282793         2611
# Op1030            86.339491         3.300424         2027
# Op1037            86.337911         3.173375         1864

# %% [markdown]
# ## CORRELATION CHECK ACROSS NUMERIC VARIABLES

# %%
corr_matrix = df[numeric_cols + ["Production Efficiency (%)","Defect Rate (%)"]].corr()
corr_matrix
# Out:
#                            Planned Production  Actual Production  \
# Planned Production                   1.000000           0.974214
# Actual Production                    0.974214           1.000000
# Defective Units                      0.447587           0.449101
# Downtime (Minutes)                  -0.022180          -0.023139
# Production Hours                     0.033498           0.042671
# Energy Consumption (kWh)            -0.025141          -0.022467
# Maintenance Cost ($)                -0.008834          -0.008065
# Unit Production Cost ($)            -0.029499          -0.027859
# Temperature (°C)                    -0.075841          -0.076264
# Humidity (%)                        -0.015714          -0.012178
# Quality Inspection Score            -0.004881          -0.006712
# Production Efficiency (%)            0.285487           0.484101
# Defect Rate (%)                      0.014088           0.000347
#
#                            Defective Units  Downtime (Minutes)  \
# Planned Production                0.447587           -0.022180
# Actual Production                 0.449101           -0.023139
# Defective Units                   1.000000           -0.049287
# Downtime (Minutes)               -0.049287            1.000000
# Production Hours                 -0.025055            0.027539
# Energy Consumption (kWh)          0.010849            0.035542
# Maintenance Cost ($)              0.020691            0.063544
# Unit Production Cost ($)         -0.000388           -0.008965
# Temperature (°C)                 -0.049004            0.010773
# Humidity (%)                     -0.041144           -0.003690
# Quality Inspection Score          0.005681            0.005908
# Production Efficiency (%)         0.175678           -0.013503
# Defect Rate (%)                   0.854805           -0.037762
#
#                            Production Hours  Energy Consumption (kWh)  \
# Planned Production                 0.033498                 -0.025141
# Actual Production                  0.042671                 -0.022467
# Defective Units                   -0.025055                  0.010849
# Downtime (Minutes)                 0.027539                  0.035542
# Production Hours                   1.000000                  0.014096
# Energy Consumption (kWh)           0.014096                  1.000000
# Maintenance Cost ($)              -0.039166                  0.045929
# Unit Production Cost ($)          -0.039295                 -0.018397
# Temperature (°C)                   0.044133                 -0.011379
# Humidity (%)                       0.000653                 -0.014775
# Quality Inspection Score           0.043613                 -0.019064
# Production Efficiency (%)          0.055505                 -0.003783
# Defect Rate (%)                   -0.047214                  0.019002
#
#                            Maintenance Cost ($)  Unit Production Cost ($)  \
# Planned Production                    -0.008834                 -0.029499
# Actual Production                     -0.008065                 -0.027859
# Defective Units                        0.020691                 -0.000388
# Downtime (Minutes)                     0.063544                 -0.008965
# Production Hours                      -0.039166                 -0.039295
# Energy Consumption (kWh)               0.045929                 -0.018397
# Maintenance Cost ($)                   1.000000                 -0.005454
# Unit Production Cost ($)              -0.005454                  1.000000
# Temperature (°C)                      -0.042048                  0.026063
# Humidity (%)                          -0.023171                 -0.019195
# Quality Inspection Score              -0.016298                 -0.011830
# Production Efficiency (%)             -0.003653                 -0.014022
# Defect Rate (%)                        0.029440                  0.004175
#
#                            Temperature (°C)  Humidity (%)  \
# Planned Production                -0.075841     -0.015714
# Actual Production                 -0.076264     -0.012178
# Defective Units                   -0.049004     -0.041144
# Downtime (Minutes)                 0.010773     -0.003690
# Production Hours                   0.044133      0.000653
# Energy Consumption (kWh)          -0.011379     -0.014775
# Maintenance Cost ($)              -0.042048     -0.023171
# Unit Production Cost ($)           0.026063     -0.019195
# Temperature (°C)                   1.000000      0.049205
# Humidity (%)                       0.049205      1.000000
# Quality Inspection Score          -0.006345      0.036276
# Production Efficiency (%)         -0.035937      0.006444
# Defect Rate (%)                   -0.026107     -0.030836
#
#                            Quality Inspection Score  \
# Planned Production                        -0.004881
# Actual Production                         -0.006712
# Defective Units                            0.005681
# Downtime (Minutes)                         0.005908
# Production Hours                           0.043613
# Energy Consumption (kWh)                  -0.019064
# Maintenance Cost ($)                      -0.016298
# Unit Production Cost ($)                  -0.011830
# Temperature (°C)                          -0.006345
# Humidity (%)                               0.036276
# Quality Inspection Score                   1.000000
# Production Efficiency (%)                 -0.001978
# Defect Rate (%)                            0.013528
#
#                            Production Efficiency (%)  Defect Rate (%)
# Planned Production                          0.285487         0.014088
# Actual Production                           0.484101         0.000347
# Defective Units                             0.175678         0.854805
# Downtime (Minutes)                         -0.013503        -0.037762
# Production Hours                            0.055505        -0.047214
# Energy Consumption (kWh)                   -0.003783         0.019002
# Maintenance Cost ($)                       -0.003653         0.029440
# Unit Production Cost ($)                   -0.014022         0.004175
# Temperature (°C)                           -0.035937        -0.026107
# Humidity (%)                                0.006444        -0.030836
# Quality Inspection Score                   -0.001978         0.013528
# Production Efficiency (%)                   1.000000        -0.059918
# Defect Rate (%)                            -0.059918         1.000000

# %% [markdown]
# # TASK 4: GROUPING AND AGGREGATION

# %% [markdown]
# ## MULTI-LEVEL GROUPING - FACTORY * PRODUCTION LINE

# %%
factory_line_group = df.groupby(["Factory","Production Line"]).agg(
 avg_efficiency=("Production Efficiency (%)","mean"),
 avg_defect_rate=("Defect Rate (%)","mean"),
 total_downtime=("Downtime (Minutes)","sum"),
 avg_quality_score=("Quality Inspection Score","mean")
).reset_index()
factory_line_group.sort_values("avg_efficiency", ascending=False)
# Out:
#       Factory Production Line  avg_efficiency  avg_defect_rate  \
# 11  Factory C          Line D       94.190903         3.777727
# 8   Factory C          Line A       93.646311         3.970981
# 6   Factory B          Line C       93.616045         3.587027
# 4   Factory B          Line A       93.549419         4.021147
# 0   Factory A          Line A       92.827203         3.894962
# 5   Factory B          Line B       92.792035         4.373636
# 7   Factory B          Line D       92.728489         3.854557
# 3   Factory A          Line D       92.673032         3.937529
# 1   Factory A          Line B       92.345653         3.938178
# 10  Factory C          Line C       92.294050         3.783711
# 2   Factory A          Line C       91.551766         4.247559
# 9   Factory C          Line B       91.297406         3.907939
#
#     total_downtime  avg_quality_score
# 11          5650.0          80.679167
# 8           4170.0          80.178481
# 6           5173.0          81.272527
# 4           5302.0          81.145882
# 0           6032.0          77.936735
# 5           5201.0          79.964368
# 7           5339.0          80.203488
# 3           4451.0          80.162162
# 1           5309.0          79.604762
# 10          4606.0          78.622368
# 2           4655.0          79.895775
# 9           4133.0          80.064384

# %% [markdown]
# ## SHIFT BASED COMPARISON ACROSS FACTORIES

# %%
shift_factory_group = df.groupby(["Factory","Shift"]).agg(
 avg_efficiency=("Production Efficiency (%)","mean"),
 avg_downtime=("Downtime (Minutes)","mean"),
 avg_defect_rate=("Defect Rate (%)","mean")
).reset_index()
shift_factory_group
# Out:
#      Factory      Shift  avg_efficiency  avg_downtime  avg_defect_rate
# 0  Factory A  Afternoon       91.175313     62.901961         4.131938
# 1  Factory A    Morning       92.630292     63.092593         3.981793
# 2  Factory A      Night       93.231854     61.683761         3.880134
# 3  Factory B  Afternoon       93.465512     53.475410         3.923996
# 4  Factory B    Morning       92.589543     63.857143         3.909853
# 5  Factory B      Night       93.439100     63.817391         4.031167
# 6  Factory C  Afternoon       91.819643     56.127451         3.913514
# 7  Factory C    Morning       93.437231     57.051282         3.831565
# 8  Factory C      Night       93.539847     58.657143         3.826088

# %% [markdown]
# ## PRODUCT CATEGORY PERFORMANCE BY FACTORY

# %%
machine_type_group = df.groupby(["Factory","Machine Type"]).agg(
 avg_downtime=("Downtime (Minutes)","mean"),
 avg_maintenance_cost=("Maintenance Cost ($)","mean"),
 avg_efficiency=("Production Efficiency (%)","mean")
).reset_index()
machine_type_group
# Out:
#      Factory    Machine Type  avg_downtime  avg_maintenance_cost  \
# 0  Factory A       Automatic     62.252336           1342.852430
# 1  Factory A          Manual     67.259615           1212.815577
# 2  Factory A  Semi-Automatic     58.543103           1447.326810
# 3  Factory B       Automatic     60.137615           1280.458716
# 4  Factory B          Manual     56.975806           1341.001935
# 5  Factory B  Semi-Automatic     63.750000           1354.511034
# 6  Factory C       Automatic     54.146789           1293.897523
# 7  Factory C          Manual     58.254717           1273.418208
# 8  Factory C  Semi-Automatic     59.467890           1295.362477
#
#    avg_efficiency
# 0       91.456040
# 1       92.356288
# 2       93.286468
# 3       92.949755
# 4       93.478970
# 5       93.063812
# 6       92.946139
# 7       92.465926
# 8       93.458041

# %% [markdown]
# ## MACHINE TYPE PERFORMANCE ACROSS FACTORIES

# %%
df["Month"] = df["Production Date"].dt.to_period("M")

# %%
monthly_trend = df.groupby("Month").agg(
 total_production=("Actual Production","sum"),
 avg_efficiency=("Production Efficiency (%)","mean"),
 avg_defect_rate=("Defect Rate (%)","mean"),
 total_downtime=("Downtime (Minutes)","sum"),
 total_energy=("Energy Consumption (kWh)","sum")
).reset_index()
monthly_trend
# Out:
#       Month  total_production  avg_efficiency  avg_defect_rate  \
# 0   2025-01             30471       93.819789         3.944292
# 1   2025-02             30070       93.196424         3.614095
# 2   2025-03             31334       92.514333         4.094961
# 3   2025-04             30423       93.093091         4.208146
# 4   2025-05             22965       93.663842         3.281890
# 5   2025-06             26524       92.803137         4.195215
# 6   2025-07             22476       91.708569         4.131949
# 7   2025-08             26201       93.540496         4.032586
# 8   2025-09             23844       92.717768         3.627062
# 9   2025-10             23173       92.385519         4.223404
# 10  2025-11             23177       92.795265         3.916512
# 11  2025-12             28543       91.876999         3.877061
#
#     total_downtime  total_energy
# 0           5252.0         71636
# 1           5692.0         67223
# 2           5836.0         63064
# 3           5537.0         72917
# 4           4405.0         55959
# 5           5045.0         55142
# 6           4821.0         58819
# 7           4781.0         55607
# 8           4111.0         55272
# 9           4889.0         59022
# 10          4120.0         51059
# 11          5532.0         70548

# %% [markdown]
# ## TIME BASED TRENDS -  MONTHLY AGGREGATION

# %%
pivot_efficiency = df.pivot_table(
 values="Production Efficiency (%)",
 index="Factory",
 columns="Shift",
 aggfunc="mean"
)
pivot_efficiency
# Out:
# Shift      Afternoon    Morning      Night
# Factory
# Factory A  91.175313  92.630292  93.231854
# Factory B  93.465512  92.589543  93.439100
# Factory C  91.819643  93.437231  93.539847

# %% [markdown]
# ## PIVOT TABLE - EFFICIENCY BY FACTORY VS SHIFT

# %%
pivot_defects = df.pivot_table(
 values="Defect Rate (%)",
 index="Product Category",
 columns="Factory",
 aggfunc="mean"
)
pivot_defects
# Out:
# Factory           Factory A  Factory B  Factory C
# Product Category
# Air Conditioner    3.761197   3.739806   3.691782
# Microwave          4.008453   4.127411   3.547813
# Refrigerator       3.779449   3.800320   3.812255
# Television         4.244474   3.959731   3.588030
# Washing Machine    4.217875   4.103546   4.671158

# %% [markdown]
# ## COST EFFICIENCY RANKING - COMBINE COST, QUALITY, AND OUTPUT INTO ONE COMPARISON

# %%
cost_efficiency = df.groupby("Factory").agg(
 avg_unit_cost=("Unit Production Cost ($)","mean"),
 avg_quality=("Quality Inspection Score","mean"),
 total_output=("Actual Production","sum")
).reset_index()

cost_efficiency["Output per Cost Unit"] = cost_efficiency["total_output"] / cost_efficiency["avg_unit_cost"]
cost_efficiency.sort_values('Output per Cost Unit', ascending=False)
# Out:
#      Factory  avg_unit_cost  avg_quality  total_output  Output per Cost Unit
# 1  Factory B     237.894556    80.652149        113887            478.728904
# 0  Factory A     239.412936    79.294190        103112            430.686837
# 2  Factory C     248.185741    79.936111        102202            411.796422

# %% [markdown]
# ## IDENTIFY BEST/WORST COMBINATION

# %%
factory_line_group.nlargest(3, "avg_efficiency")
# Out:
#       Factory Production Line  avg_efficiency  avg_defect_rate  \
# 11  Factory C          Line D       94.190903         3.777727
# 8   Factory C          Line A       93.646311         3.970981
# 6   Factory B          Line C       93.616045         3.587027
#
#     total_downtime  avg_quality_score
# 11          5650.0          80.679167
# 8           4170.0          80.178481
# 6           5173.0          81.272527

# %%
factory_line_group.nsmallest(3, "avg_efficiency")
# Out:
#       Factory Production Line  avg_efficiency  avg_defect_rate  \
# 9   Factory C          Line B       91.297406         3.907939
# 2   Factory A          Line C       91.551766         4.247559
# 10  Factory C          Line C       92.294050         3.783711
#
#     total_downtime  avg_quality_score
# 9           4133.0          80.064384
# 2           4655.0          79.895775
# 10          4606.0          78.622368

# %% [markdown]
# # TASK 5: DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %% [markdown]
# ## PRODUCTION EFFICIENCY BY FACTORY

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=factory_perf.reset_index(), x='Factory', y='avg_efficiency')
plt.title('Average Production Efficiency by Factory')
plt.ylabel('Efficiency (%)')
plt.show()

# %% [markdown]
# ## DEFECT RATE BY PRODUCTION LINE

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=line_perf.reset_index(), x='Production Line', y='avg_defect_rate', hue='Factory')
plt.title('Average Defect Rate by Production Line')
plt.ylabel('Defect Rate (%)')
plt.show()

# %% [markdown]
# ## MACHINE DOWNTIME DISTRIBUTION

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='Machine Type', y='Downtime (Minutes)')
plt.title('Downtime Distribution by Machine Type')
plt.show()

# %% [markdown]
# ## QUALITY INSPECTION SCORE BY PRODUCT CATEGORY

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=quality_by_product.reset_index(), x='Product Category', y='avg_quality_score')
plt.title('Average Quality Score by Product Category')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ## ENERGY CONSUMPTION VS ACTUAL PRODUCTION

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Actual Production', y='Energy Consumption (kWh)', hue='Factory')
plt.title('Energy Consumption vs Actual Production')
plt.show()

# %% [markdown]
# ## MAINTENANCE COST VS DOWNTIME

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Downtime (Minutes)', y='Maintenance Cost ($)', hue='Machine Type')
plt.title('Maintenance Cost vs Downtime')
plt.show()

# %% [markdown]
# ## MONTHLY PRODUCTION TREND

# %%
plt.figure(figsize=(10,5))
monthly_trend_plot = monthly_trend.copy()
monthly_trend_plot['Month'] = monthly_trend_plot['Month'].astype(str)
sns.lineplot(data=monthly_trend_plot, x='Month', y='total_production', marker='o')
plt.title('Monthly Total Production Trend')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## HEATMAP - EFFICIENCY BY FACTORY VS SHIFT

# %%
plt.figure(figsize=(8,5))
sns.heatmap(pivot_efficiency, annot=True, cmap='YlGnBu', fmt='.1f')
plt.title('Efficiency Heatmap: Factory vs Shift')
plt.show()

# %% [markdown]
# ## HEATMAP - DEFECT RATE BY PRODUCT CATEGORY VS FACTORY

# %%
plt.figure(figsize=(8,5))
sns.heatmap(pivot_defects, annot=True, cmap='Reds', fmt='.1f')
plt.title('Defect Rate Heatmap: Product Category vs Factory')
plt.show()

# %% [markdown]
# ## CORRELATION HEATMAP ACROSS NUMERIC VARIABLES

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Key Metrics')
plt.show()

# %% [markdown]
# ## OPERATOR PERFORMANCE - TOP VS BOTTOM

# %%
top_bottom = pd.concat([operator_perf.head(5), operator_perf.tail(5)]).reset_index()
plt.figure(figsize=(8,6))
sns.barplot(data=top_bottom, y='Operator ID', x='avg_efficiency', palette='coolwarm')
plt.title('Top 5 vs Bottom 5 Operators by Efficiency')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_24668\1270900273.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_bottom, y='Operator ID', x='avg_efficiency', palette='coolwarm')
